# %% [markdown]
# # user input

# %%
entered_value=input('enter some value: ')
# Out:
# enter some value: 123

# %%
entered_value
# Out:
# '123'

# %%
name=input('enter your name ').lstrip().lower()
shoe_size=int(input('enter your shoe size '))
# Out:
# enter your name     Sian
# enter your shoe size 38

# %%
type(shoe_size)
# Out:
# int

# %%
name
# Out:
# 'sian'

# %% [markdown]
# ## exception handling

# %%
try:
    shoe_size=int(input('enter your shoe size in whole numbers: '))
    print('great job, thats a shoe size. the number is ',shoe_size)

except ValueError:
    print('this is not a whole number, try again....')
# Out:
# enter your shoe size in whole numbers: sian
# this is not a whole number, try again....

# %%
if len(input('enter a song... ')) < 2:
    print('did you forget to enter a song, dumbass?')
# Out:
# enter a song...
# did you forget to enter a song, dumbass?

# %% [markdown]
# ## is this in a list of values

# %%
guest_list=['sian','andy','miguel','roger']

# %%
yourname=input('tell me your name please ')
# Out:
# tell me your name please Cath

# %%
if yourname in guest_list:
    print('welcome you are on the guest list, get a free cocktail ')
else:
    print('your name is not down and youre not coming in')
# Out:
# your name is not down and youre not coming in

# %% [markdown]
# ## select random items

# %%
from random import randrange

# %%
i=randrange(len(guest_list))

# %%
item=guest_list[i]

# %%
print('randomly selected item '+ item + ' is present at index: '+str(i))
# Out:
# randomly selected item miguel is present at index: 2

# %% [markdown]
# # APIs

# %%
import requests 
import json

# %%
google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# ## Github API

# %%
github_response=requests.get('https://api.github.com/users/siandav/events/public') # replace my github name with yours
github_response.status_code
# Out:
# 200

# %%
github_response.json()
# Out:
# [{'id': '21957552104',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9969162747,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6289f6dc806212be1d87cad754f164c8a86e589b',
#    'before': '679b379ca682313aa2e4fc4272e0e3b204c53baa',
#    'commits': [{'sha': '6289f6dc806212be1d87cad754f164c8a86e589b',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'push contents tuesday multi page scrape  user input and api',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/6289f6dc806212be1d87cad754f164c8a86e589b'}]},
#   'public': True,
#   'created_at': '2022-05-24T13:22:14Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21954746474',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9967790325,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '679b379ca682313aa2e4fc4272e0e3b204c53baa',
#    'before': '1270664c79d70fb78070bb79fb0a12c51bde3446',
#    'commits': [{'sha': '679b379ca682313aa2e4fc4272e0e3b204c53baa',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create Multiple_page_scraping.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/679b379ca682313aa2e4fc4272e0e3b204c53baa'}]},
#   'public': True,
#   'created_at': '2022-05-24T11:03:14Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21939381755',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9960175261,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1270664c79d70fb78070bb79fb0a12c51bde3446',
#    'before': 'c20b305988c7c42e0d12a97cec4b2cc01c79d1dd',
#    'commits': [{'sha': '1270664c79d70fb78070bb79fb0a12c51bde3446',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Update webscrape_one_page.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/1270664c79d70fb78070bb79fb0a12c51bde3446'}]},
#   'public': True,
#   'created_at': '2022-05-23T16:27:42Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21939180771',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9960078831,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c20b305988c7c42e0d12a97cec4b2cc01c79d1dd',
#    'before': '4d8d746deaff9ee62ac63f1753b259d64ae73a72',
#    'commits': [{'sha': 'c20b305988c7c42e0d12a97cec4b2cc01c79d1dd',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Update webscrape_one_page.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/c20b305988c7c42e0d12a97cec4b2cc01c79d1dd'}]},
#   'public': True,
#   'created_at': '2022-05-23T16:16:58Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21936475042',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9958783826,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '4d8d746deaff9ee62ac63f1753b259d64ae73a72',
#    'before': '12b437ac31598c07e86950f3e222cc0de16bd6a3',
#    'commits': [{'sha': 'ba26d1043b77bfd35ad3ed0bb21add261ecbb0b0',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'push week 6 end and first web scrape notebook',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/ba26d1043b77bfd35ad3ed0bb21add261ecbb0b0'},
#     {'sha': '4d8d746deaff9ee62ac63f1753b259d64ae73a72',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': "Merge branch 'main' of https://github.com/student-IH-labs-and-stuff/BCNDATA2022",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/4d8d746deaff9ee62ac63f1753b259d64ae73a72'}]},
#   'public': True,
#   'created_at': '2022-05-23T14:11:26Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21899249118',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9937995940,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '12b437ac31598c07e86950f3e222cc0de16bd6a3',
#    'before': '46a6a8c9567208e0ca49de7c97246ca954c46c62',
#    'commits': [{'sha': '12b437ac31598c07e86950f3e222cc0de16bd6a3',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_Interm.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/12b437ac31598c07e86950f3e222cc0de16bd6a3'}]},
#   'public': True,
#   'created_at': '2022-05-20T11:48:42Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21899217636',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9937980234,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '46a6a8c9567208e0ca49de7c97246ca954c46c62',
#    'before': '832f4ea1b01d57fe326d81348ec5368f76168a71',
#    'commits': [{'sha': '46a6a8c9567208e0ca49de7c97246ca954c46c62',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_Interm.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/46a6a8c9567208e0ca49de7c97246ca954c46c62'}]},
#   'public': True,
#   'created_at': '2022-05-20T11:46:42Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21854535434',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9916412295,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '832f4ea1b01d57fe326d81348ec5368f76168a71',
#    'before': 'b1d8f6b9828e55ac6680038e41114957db0570f8',
#    'commits': [{'sha': '832f4ea1b01d57fe326d81348ec5368f76168a71',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/832f4ea1b01d57fe326d81348ec5368f76168a71'}]},
#   'public': True,
#   'created_at': '2022-05-18T12:58:47Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21851057251',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9914703074,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b1d8f6b9828e55ac6680038e41114957db0570f8',
#    'before': '6d9764a31946c0fe0ac40064f63bd614722da046',
#    'commits': [{'sha': 'b1d8f6b9828e55ac6680038e41114957db0570f8',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/b1d8f6b9828e55ac6680038e41114957db0570f8'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:56:26Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21851033362',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9914691250,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6d9764a31946c0fe0ac40064f63bd614722da046',
#    'before': '468bcbf7893980775a15cbbef2a10a110f5caf3c',
#    'commits': [{'sha': '6d9764a31946c0fe0ac40064f63bd614722da046',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/6d9764a31946c0fe0ac40064f63bd614722da046'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:55:14Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21850954165',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9914652525,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '468bcbf7893980775a15cbbef2a10a110f5caf3c',
#    'before': '382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc',
#    'commits': [{'sha': '468bcbf7893980775a15cbbef2a10a110f5caf3c',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/468bcbf7893980775a15cbbef2a10a110f5caf3c'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:51:17Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21850931279',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9914641197,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc',
#    'before': '338af8264b2122dba4309a13d4fbd84715113a6e',
#    'commits': [{'sha': '382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:50:07Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21850902764',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9914627037,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '338af8264b2122dba4309a13d4fbd84715113a6e',
#    'before': 'bce933756940ae0025e0ea1b1c2b12c6909161f3',
#    'commits': [{'sha': '338af8264b2122dba4309a13d4fbd84715113a6e',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/338af8264b2122dba4309a13d4fbd84715113a6e'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:48:44Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21850880511',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9914615569,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bce933756940ae0025e0ea1b1c2b12c6909161f3',
#    'before': '5a2532c795cfb3cce5843080e7d144796de4fb2c',
#    'commits': [{'sha': 'bce933756940ae0025e0ea1b1c2b12c6909161f3',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/bce933756940ae0025e0ea1b1c2b12c6909161f3'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:47:41Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21850855033',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9914602510,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5a2532c795cfb3cce5843080e7d144796de4fb2c',
#    'before': '15a0f51296d29eb70d7f29f6113d3af93bbb3032',
#    'commits': [{'sha': '5a2532c795cfb3cce5843080e7d144796de4fb2c',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/5a2532c795cfb3cce5843080e7d144796de4fb2c'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:46:25Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21850770344',
#   'type': 'IssuesEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 328164258,
#    'name': 'ironhack-edu/data_8.09_activities',
#    'url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities/issues/1',
#     'repository_url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities',
#     'labels_url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities/issues/1/events',
#     'html_url': 'https://github.com/ironhack-edu/data_8.09_activities/issues/1',
#     'id': 1239698563,
#     'node_id': 'I_kwDOE49jos5J5EyD',
#     'number': 1,
#     'title': 'there is no link',
#     'user': {'login': 'siandav',
#      'id': 71644535,
#      'node_id': 'MDQ6VXNlcjcxNjQ0NTM1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/siandav',
#      'html_url': 'https://github.com/siandav',
#      'followers_url': 'https://api.github.com/users/siandav/followers',
#      'following_url': 'https://api.github.com/users/siandav/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/siandav/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/siandav/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/siandav/subscriptions',
#      'organizations_url': 'https://api.github.com/users/siandav/orgs',
#      'repos_url': 'https://api.github.com/users/siandav/repos',
#      'events_url': 'https://api.github.com/users/siandav/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/siandav/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-05-18T09:42:13Z',
#     'updated_at': '2022-05-18T09:42:13Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'https://github.com/ironhack-edu/data_8.09_activities/blob/master/8.09_activity_4.md\r\n\r\ninstruction says read this article but there is no article \r\n\r\n@sandrabosk ',
#     'reactions': {'url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities/issues/1/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ironhack-edu/data_8.09_activities/issues/1/timeline',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-05-18T09:42:14Z'},
#  {'id': '21848870383',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9913642150,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '15a0f51296d29eb70d7f29f6113d3af93bbb3032',
#    'before': '3b4c565822ba54d4297f8c6171729a57ffa499fc',
#    'commits': [{'sha': '15a0f51296d29eb70d7f29f6113d3af93bbb3032',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Geocoding_images.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/15a0f51296d29eb70d7f29f6113d3af93bbb3032'}]},
#   'public': True,
#   'created_at': '2022-05-18T08:08:11Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21834900966',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9906524495,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3b4c565822ba54d4297f8c6171729a57ffa499fc',
#    'before': '7163e88f2a2880a7f7410f362b84cdc7237f2356',
#    'commits': [{'sha': '3b4c565822ba54d4297f8c6171729a57ffa499fc',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create Dictionaries_lists_nested_17May.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/3b4c565822ba54d4297f8c6171729a57ffa499fc'}]},
#   'public': True,
#   'created_at': '2022-05-17T15:06:54Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21811611471',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9895263279,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '7163e88f2a2880a7f7410f362b84cdc7237f2356',
#    'before': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#    'commits': [{'sha': '715975215999642a75b2dde2475ff10cc12309a9',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'github tips to correct week',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/715975215999642a75b2dde2475ff10cc12309a9'},
#     {'sha': '7163e88f2a2880a7f7410f362b84cdc7237f2356',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': "Merge branch 'main' of https://github.com/student-IH-labs-and-stuff/BCNDATA2022",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/7163e88f2a2880a7f7410f362b84cdc7237f2356'}]},
#   'public': True,
#   'created_at': '2022-05-16T14:54:30Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21805821771',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9892461716,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#    'before': 'af3fb301741793d1d481f1f6a91213c72c678dde',
#    'commits': [{'sha': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/fd35099aaa6bc1913262e6be3d91a61277d21b94'}]},
#   'public': True,
#   'created_at': '2022-05-16T10:13:13Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21804865302',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9891999912,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'af3fb301741793d1d481f1f6a91213c72c678dde',
#    'before': 'fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d',
#    'commits': [{'sha': '15e27b2ecb73df710a567f34dd3c2ba715600dc8',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update case study',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/15e27b2ecb73df710a567f34dd3c2ba715600dc8'},
#     {'sha': 'af3fb301741793d1d481f1f6a91213c72c678dde',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create stats_16_May_22.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/af3fb301741793d1d481f1f6a91213c72c678dde'}]},
#   'public': True,
#   'created_at': '2022-05-16T09:23:22Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21756763818',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9865804288,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d',
#    'before': 'd860d12fe393274daae88bbafbfeee404204bec5',
#    'commits': [{'sha': 'fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_intro.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d'}]},
#   'public': True,
#   'created_at': '2022-05-12T14:50:25Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21756687813',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9865768271,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd860d12fe393274daae88bbafbfeee404204bec5',
#    'before': 'bfabaab502edb4f67e696edebade1b7e48875d6c',
#    'commits': [{'sha': 'd860d12fe393274daae88bbafbfeee404204bec5',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update data sources week 6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/d860d12fe393274daae88bbafbfeee404204bec5'}]},
#   'public': True,
#   'created_at': '2022-05-12T14:47:10Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21756380691',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9865621319,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bfabaab502edb4f67e696edebade1b7e48875d6c',
#    'before': '79bc6bc74ce60383260e639e59c10c1a89aaddd2',
#    'commits': [{'sha': 'bfabaab502edb4f67e696edebade1b7e48875d6c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'move around data for week 6 classes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/bfabaab502edb4f67e696edebade1b7e48875d6c'}]},
#   'public': True,
#   'created_at': '2022-05-12T14:33:52Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21691895914',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9833894424,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '79bc6bc74ce60383260e639e59c10c1a89aaddd2',
#    'before': 'ea807f74bbd67bb865856e837b960bc9f5c5236c',
#    'commits': [{'sha': '79bc6bc74ce60383260e639e59c10c1a89aaddd2',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create abTesting.xlsx',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/79bc6bc74ce60383260e639e59c10c1a89aaddd2'}]},
#   'public': True,
#   'created_at': '2022-05-09T16:05:45Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21691273252',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 304322422,
#    'name': 'student-IH-labs-and-stuff/BER-DAFT-OCT20-Sian',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-OCT20-Sian'},
#   'payload': {'push_id': 9833596447,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e836d3cc8ec3b0f7950c907a1f524c877ce69853',
#    'before': '2ee223000058e17daa85e9181d3fd13fe7adb395',
#    'commits': [{'sha': 'e836d3cc8ec3b0f7950c907a1f524c877ce69853',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'updates_all',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-OCT20-Sian/commits/e836d3cc8ec3b0f7950c907a1f524c877ce69853'}]},
#   'public': True,
#   'created_at': '2022-05-09T15:34:15Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21691264622',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 336077917,
#    'name': 'student-IH-labs-and-stuff/BER-DAFT-MAR21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21'},
#   'payload': {'push_id': 9833592419,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8c471c582ded0906fa528ceb67c8f48ac8dedf35',
#    'before': '4ddc4bb3ae0629df651e470587af85bf910ce041',
#    'commits': [{'sha': '8c471c582ded0906fa528ceb67c8f48ac8dedf35',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'updates_all',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21/commits/8c471c582ded0906fa528ceb67c8f48ac8dedf35'}]},
#   'public': True,
#   'created_at': '2022-05-09T15:33:50Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21691258966',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 9833589808,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '829c0d752c95f5d4e3b2bc8e8809f51a30cb1884',
#    'before': '8e72caa358e8e5239a8bc140fa6995c2fdcc713b',
#    'commits': [{'sha': '829c0d752c95f5d4e3b2bc8e8809f51a30cb1884',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'updates_all',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/829c0d752c95f5d4e3b2bc8e8809f51a30cb1884'}]},
#   'public': True,
#   'created_at': '2022-05-09T15:33:34Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21691251165',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 414600085,
#    'name': 'student-IH-labs-and-stuff/BCNDATA1021',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA1021'},
#   'payload': {'push_id': 9833586044,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6bb68f66c0dae9d3ec587cce77b5cad7b8f7dea1',
#    'before': '6d4e17ac9a8c69a7a2f867a08ea75e8bfe16213c',
#    'commits': [{'sha': '6bb68f66c0dae9d3ec587cce77b5cad7b8f7dea1',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'updates_all',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA1021/commits/6bb68f66c0dae9d3ec587cce77b5cad7b8f7dea1'}]},
#   'public': True,
#   'created_at': '2022-05-09T15:33:11Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21682219125',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'push_id': 9829237028,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ea807f74bbd67bb865856e837b960bc9f5c5236c',
#    'before': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#    'commits': [{'sha': 'ea807f74bbd67bb865856e837b960bc9f5c5236c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create fri_6_may.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022/commits/ea807f74bbd67bb865856e837b960bc9f5c5236c'}]},
#   'public': True,
#   'created_at': '2022-05-09T07:52:35Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}}]

# %%
import pandas as pd

# %%
pd.DataFrame(github_response.json())
# Out:
#              id         type  \
# 0   21957552104    PushEvent
# 1   21954746474    PushEvent
# 2   21939381755    PushEvent
# 3   21939180771    PushEvent
# 4   21936475042    PushEvent
# 5   21899249118    PushEvent
# 6   21899217636    PushEvent
# 7   21854535434    PushEvent
# 8   21851057251    PushEvent
# 9   21851033362    PushEvent
# 10  21850954165    PushEvent
# 11  21850931279    PushEvent
# 12  21850902764    PushEvent
# 13  21850880511    PushEvent
# 14  21850855033    PushEvent
# 15  21850770344  IssuesEvent
# 16  21848870383    PushEvent
# 17  21834900966    PushEvent
# 18  21811611471    PushEvent
# 19  21805821771    PushEvent
# 20  21804865302    PushEvent
# 21  21756763818    PushEvent
# 22  21756687813    PushEvent
# 23  21756380691    PushEvent
# 24  21691895914    PushEvent
# 25  21691273252    PushEvent
# 26  21691264622    PushEvent
# 27  21691258966    PushEvent
# 28  21691251165    PushEvent
# 29  21682219125    PushEvent
#
#                                                 actor  \
# 0   {'id': 71644535, 'login': 'siandav', 'display_...
# 1   {'id': 71644535, 'login': 'siandav', 'display_...
# 2   {'id': 71644535, 'login': 'siandav', 'display_...
# 3   {'id': 71644535, 'login': 'siandav', 'display_...
# 4   {'id': 71644535, 'login': 'siandav', 'display_...
# 5   {'id': 71644535, 'login': 'siandav', 'display_...
# 6   {'id': 71644535, 'login': 'siandav', 'display_...
# 7   {'id': 71644535, 'login': 'siandav', 'display_...
# 8   {'id': 71644535, 'login': 'siandav', 'display_...
# 9   {'id': 71644535, 'login': 'siandav', 'display_...
# 10  {'id': 71644535, 'login': 'siandav', 'display_...
# 11  {'id': 71644535, 'login': 'siandav', 'display_...
# 12  {'id': 71644535, 'login': 'siandav', 'display_...
# 13  {'id': 71644535, 'login': 'siandav', 'display_...
# 14  {'id': 71644535, 'login': 'siandav', 'display_...
# 15  {'id': 71644535, 'login': 'siandav', 'display_...
# 16  {'id': 71644535, 'login': 'siandav', 'display_...
# 17  {'id': 71644535, 'login': 'siandav', 'display_...
# 18  {'id': 71644535, 'login': 'siandav', 'display_...
# 19  {'id': 71644535, 'login': 'siandav', 'display_...
# 20  {'id': 71644535, 'login': 'siandav', 'display_...
# 21  {'id': 71644535, 'login': 'siandav', 'display_...
# 22  {'id': 71644535, 'login': 'siandav', 'display_...
# 23  {'id': 71644535, 'login': 'siandav', 'display_...
# 24  {'id': 71644535, 'login': 'siandav', 'display_...
# 25  {'id': 71644535, 'login': 'siandav', 'display_...
# 26  {'id': 71644535, 'login': 'siandav', 'display_...
# 27  {'id': 71644535, 'login': 'siandav', 'display_...
# 28  {'id': 71644535, 'login': 'siandav', 'display_...
# 29  {'id': 71644535, 'login': 'siandav', 'display_...
#
#                                                  repo  \
# 0   {'id': 446439899, 'name': 'student-IH-labs-and...
# 1   {'id': 446439899, 'name': 'student-IH-labs-and...
# 2   {'id': 446439899, 'name': 'student-IH-labs-and...
# 3   {'id': 446439899, 'name': 'student-IH-labs-and...
# 4   {'id': 446439899, 'name': 'student-IH-labs-and...
# 5   {'id': 446439899, 'name': 'student-IH-labs-and...
# 6   {'id': 446439899, 'name': 'student-IH-labs-and...
# 7   {'id': 446439899, 'name': 'student-IH-labs-and...
# 8   {'id': 446439899, 'name': 'student-IH-labs-and...
# 9   {'id': 446439899, 'name': 'student-IH-labs-and...
# 10  {'id': 446439899, 'name': 'student-IH-labs-and...
# 11  {'id': 446439899, 'name': 'student-IH-labs-and...
# 12  {'id': 446439899, 'name': 'student-IH-labs-and...
# 13  {'id': 446439899, 'name': 'student-IH-labs-and...
# 14  {'id': 446439899, 'name': 'student-IH-labs-and...
# 15  {'id': 328164258, 'name': 'ironhack-edu/data_8...
# 16  {'id': 446439899, 'name': 'student-IH-labs-and...
# 17  {'id': 446439899, 'name': 'student-IH-labs-and...
# 18  {'id': 446439899, 'name': 'student-IH-labs-and...
# 19  {'id': 446439899, 'name': 'student-IH-labs-and...
# 20  {'id': 446439899, 'name': 'student-IH-labs-and...
# 21  {'id': 446439899, 'name': 'student-IH-labs-and...
# 22  {'id': 446439899, 'name': 'student-IH-labs-and...
# 23  {'id': 446439899, 'name': 'student-IH-labs-and...
# 24  {'id': 446439899, 'name': 'student-IH-labs-and...
# 25  {'id': 304322422, 'name': 'student-IH-labs-and...
# 26  {'id': 336077917, 'name': 'student-IH-labs-and...
# 27  {'id': 368110379, 'name': 'student-IH-labs-and...
# 28  {'id': 414600085, 'name': 'student-IH-labs-and...
# 29  {'id': 446439899, 'name': 'student-IH-labs-and...
#
#                                               payload  public  \
# 0   {'push_id': 9969162747, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 9967790325, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 9960175261, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 9960078831, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 9958783826, 'size': 2, 'distinct_s...    True
# 5   {'push_id': 9937995940, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 9937980234, 'size': 1, 'distinct_s...    True
# 7   {'push_id': 9916412295, 'size': 1, 'distinct_s...    True
# 8   {'push_id': 9914703074, 'size': 1, 'distinct_s...    True
# 9   {'push_id': 9914691250, 'size': 1, 'distinct_s...    True
# 10  {'push_id': 9914652525, 'size': 1, 'distinct_s...    True
# 11  {'push_id': 9914641197, 'size': 1, 'distinct_s...    True
# 12  {'push_id': 9914627037, 'size': 1, 'distinct_s...    True
# 13  {'push_id': 9914615569, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 9914602510, 'size': 1, 'distinct_s...    True
# 15  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 16  {'push_id': 9913642150, 'size': 1, 'distinct_s...    True
# 17  {'push_id': 9906524495, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 9895263279, 'size': 2, 'distinct_s...    True
# 19  {'push_id': 9892461716, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 9891999912, 'size': 2, 'distinct_s...    True
# 21  {'push_id': 9865804288, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 9865768271, 'size': 1, 'distinct_s...    True
# 23  {'push_id': 9865621319, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 9833894424, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 9833596447, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 9833592419, 'size': 1, 'distinct_s...    True
# 27  {'push_id': 9833589808, 'size': 1, 'distinct_s...    True
# 28  {'push_id': 9833586044, 'size': 1, 'distinct_s...    True
# 29  {'push_id': 9829237028, 'size': 1, 'distinct_s...    True
#
#               created_at                                                org
# 0   2022-05-24T13:22:14Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 1   2022-05-24T11:03:14Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 2   2022-05-23T16:27:42Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 3   2022-05-23T16:16:58Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 4   2022-05-23T14:11:26Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 5   2022-05-20T11:48:42Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 6   2022-05-20T11:46:42Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 7   2022-05-18T12:58:47Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 8   2022-05-18T09:56:26Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 9   2022-05-18T09:55:14Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 10  2022-05-18T09:51:17Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 11  2022-05-18T09:50:07Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 12  2022-05-18T09:48:44Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 13  2022-05-18T09:47:41Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 14  2022-05-18T09:46:25Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 15  2022-05-18T09:42:14Z                                                NaN
# 16  2022-05-18T08:08:11Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 17  2022-05-17T15:06:54Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 18  2022-05-16T14:54:30Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 19  2022-05-16T10:13:13Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 20  2022-05-16T09:23:22Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 21  2022-05-12T14:50:25Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 22  2022-05-12T14:47:10Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 23  2022-05-12T14:33:52Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 24  2022-05-09T16:05:45Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 25  2022-05-09T15:34:15Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 26  2022-05-09T15:33:50Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 27  2022-05-09T15:33:34Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 28  2022-05-09T15:33:11Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 29  2022-05-09T07:52:35Z  {'id': 72746426, 'login': 'student-IH-labs-and...

# %%
github_df=pd.json_normalize(github_response.json())

# %%
github_df.iloc[:,1:25]
# Out:
#            type  public            created_at  actor.id actor.login  \
# 0     PushEvent    True  2022-05-24T13:22:14Z  71644535     siandav
# 1     PushEvent    True  2022-05-24T11:03:14Z  71644535     siandav
# 2     PushEvent    True  2022-05-23T16:27:42Z  71644535     siandav
# 3     PushEvent    True  2022-05-23T16:16:58Z  71644535     siandav
# 4     PushEvent    True  2022-05-23T14:11:26Z  71644535     siandav
# 5     PushEvent    True  2022-05-20T11:48:42Z  71644535     siandav
# 6     PushEvent    True  2022-05-20T11:46:42Z  71644535     siandav
# 7     PushEvent    True  2022-05-18T12:58:47Z  71644535     siandav
# 8     PushEvent    True  2022-05-18T09:56:26Z  71644535     siandav
# 9     PushEvent    True  2022-05-18T09:55:14Z  71644535     siandav
# 10    PushEvent    True  2022-05-18T09:51:17Z  71644535     siandav
# 11    PushEvent    True  2022-05-18T09:50:07Z  71644535     siandav
# 12    PushEvent    True  2022-05-18T09:48:44Z  71644535     siandav
# 13    PushEvent    True  2022-05-18T09:47:41Z  71644535     siandav
# 14    PushEvent    True  2022-05-18T09:46:25Z  71644535     siandav
# 15  IssuesEvent    True  2022-05-18T09:42:14Z  71644535     siandav
# 16    PushEvent    True  2022-05-18T08:08:11Z  71644535     siandav
# 17    PushEvent    True  2022-05-17T15:06:54Z  71644535     siandav
# 18    PushEvent    True  2022-05-16T14:54:30Z  71644535     siandav
# 19    PushEvent    True  2022-05-16T10:13:13Z  71644535     siandav
# 20    PushEvent    True  2022-05-16T09:23:22Z  71644535     siandav
# 21    PushEvent    True  2022-05-12T14:50:25Z  71644535     siandav
# 22    PushEvent    True  2022-05-12T14:47:10Z  71644535     siandav
# 23    PushEvent    True  2022-05-12T14:33:52Z  71644535     siandav
# 24    PushEvent    True  2022-05-09T16:05:45Z  71644535     siandav
# 25    PushEvent    True  2022-05-09T15:34:15Z  71644535     siandav
# 26    PushEvent    True  2022-05-09T15:33:50Z  71644535     siandav
# 27    PushEvent    True  2022-05-09T15:33:34Z  71644535     siandav
# 28    PushEvent    True  2022-05-09T15:33:11Z  71644535     siandav
# 29    PushEvent    True  2022-05-09T07:52:35Z  71644535     siandav
#
#    actor.display_login actor.gravatar_id  \
# 0              siandav
# 1              siandav
# 2              siandav
# 3              siandav
# 4              siandav
# 5              siandav
# 6              siandav
# 7              siandav
# 8              siandav
# 9              siandav
# 10             siandav
# 11             siandav
# 12             siandav
# 13             siandav
# 14             siandav
# 15             siandav
# 16             siandav
# 17             siandav
# 18             siandav
# 19             siandav
# 20             siandav
# 21             siandav
# 22             siandav
# 23             siandav
# 24             siandav
# 25             siandav
# 26             siandav
# 27             siandav
# 28             siandav
# 29             siandav
#
#                                actor.url  \
# 0   https://api.github.com/users/siandav
# 1   https://api.github.com/users/siandav
# 2   https://api.github.com/users/siandav
# 3   https://api.github.com/users/siandav
# 4   https://api.github.com/users/siandav
# 5   https://api.github.com/users/siandav
# 6   https://api.github.com/users/siandav
# 7   https://api.github.com/users/siandav
# 8   https://api.github.com/users/siandav
# 9   https://api.github.com/users/siandav
# 10  https://api.github.com/users/siandav
# 11  https://api.github.com/users/siandav
# 12  https://api.github.com/users/siandav
# 13  https://api.github.com/users/siandav
# 14  https://api.github.com/users/siandav
# 15  https://api.github.com/users/siandav
# 16  https://api.github.com/users/siandav
# 17  https://api.github.com/users/siandav
# 18  https://api.github.com/users/siandav
# 19  https://api.github.com/users/siandav
# 20  https://api.github.com/users/siandav
# 21  https://api.github.com/users/siandav
# 22  https://api.github.com/users/siandav
# 23  https://api.github.com/users/siandav
# 24  https://api.github.com/users/siandav
# 25  https://api.github.com/users/siandav
# 26  https://api.github.com/users/siandav
# 27  https://api.github.com/users/siandav
# 28  https://api.github.com/users/siandav
# 29  https://api.github.com/users/siandav
#
#                                      actor.avatar_url    repo.id  ...  \
# 0   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 1   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 2   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 3   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 4   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 5   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 6   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 7   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 8   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 9   https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 10  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 11  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 12  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 13  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 14  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 15  https://avatars.githubusercontent.com/u/71644535?  328164258  ...
# 16  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 17  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 18  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 19  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 20  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 21  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 22  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 23  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 24  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
# 25  https://avatars.githubusercontent.com/u/71644535?  304322422  ...
# 26  https://avatars.githubusercontent.com/u/71644535?  336077917  ...
# 27  https://avatars.githubusercontent.com/u/71644535?  368110379  ...
# 28  https://avatars.githubusercontent.com/u/71644535?  414600085  ...
# 29  https://avatars.githubusercontent.com/u/71644535?  446439899  ...
#
#    payload.distinct_size      payload.ref  \
# 0                    1.0  refs/heads/main
# 1                    1.0  refs/heads/main
# 2                    1.0  refs/heads/main
# 3                    1.0  refs/heads/main
# 4                    2.0  refs/heads/main
# 5                    1.0  refs/heads/main
# 6                    1.0  refs/heads/main
# 7                    1.0  refs/heads/main
# 8                    1.0  refs/heads/main
# 9                    1.0  refs/heads/main
# 10                   1.0  refs/heads/main
# 11                   1.0  refs/heads/main
# 12                   1.0  refs/heads/main
# 13                   1.0  refs/heads/main
# 14                   1.0  refs/heads/main
# 15                   NaN              NaN
# 16                   1.0  refs/heads/main
# 17                   1.0  refs/heads/main
# 18                   2.0  refs/heads/main
# 19                   1.0  refs/heads/main
# 20                   2.0  refs/heads/main
# 21                   1.0  refs/heads/main
# 22                   1.0  refs/heads/main
# 23                   1.0  refs/heads/main
# 24                   1.0  refs/heads/main
# 25                   1.0  refs/heads/main
# 26                   1.0  refs/heads/main
# 27                   1.0  refs/heads/main
# 28                   1.0  refs/heads/main
# 29                   1.0  refs/heads/main
#
#                                 payload.head  \
# 0   6289f6dc806212be1d87cad754f164c8a86e589b
# 1   679b379ca682313aa2e4fc4272e0e3b204c53baa
# 2   1270664c79d70fb78070bb79fb0a12c51bde3446
# 3   c20b305988c7c42e0d12a97cec4b2cc01c79d1dd
# 4   4d8d746deaff9ee62ac63f1753b259d64ae73a72
# 5   12b437ac31598c07e86950f3e222cc0de16bd6a3
# 6   46a6a8c9567208e0ca49de7c97246ca954c46c62
# 7   832f4ea1b01d57fe326d81348ec5368f76168a71
# 8   b1d8f6b9828e55ac6680038e41114957db0570f8
# 9   6d9764a31946c0fe0ac40064f63bd614722da046
# 10  468bcbf7893980775a15cbbef2a10a110f5caf3c
# 11  382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc
# 12  338af8264b2122dba4309a13d4fbd84715113a6e
# 13  bce933756940ae0025e0ea1b1c2b12c6909161f3
# 14  5a2532c795cfb3cce5843080e7d144796de4fb2c
# 15                                       NaN
# 16  15a0f51296d29eb70d7f29f6113d3af93bbb3032
# 17  3b4c565822ba54d4297f8c6171729a57ffa499fc
# 18  7163e88f2a2880a7f7410f362b84cdc7237f2356
# 19  fd35099aaa6bc1913262e6be3d91a61277d21b94
# 20  af3fb301741793d1d481f1f6a91213c72c678dde
# 21  fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d
# 22  d860d12fe393274daae88bbafbfeee404204bec5
# 23  bfabaab502edb4f67e696edebade1b7e48875d6c
# 24  79bc6bc74ce60383260e639e59c10c1a89aaddd2
# 25  e836d3cc8ec3b0f7950c907a1f524c877ce69853
# 26  8c471c582ded0906fa528ceb67c8f48ac8dedf35
# 27  829c0d752c95f5d4e3b2bc8e8809f51a30cb1884
# 28  6bb68f66c0dae9d3ec587cce77b5cad7b8f7dea1
# 29  ea807f74bbd67bb865856e837b960bc9f5c5236c
#
#                               payload.before  \
# 0   679b379ca682313aa2e4fc4272e0e3b204c53baa
# 1   1270664c79d70fb78070bb79fb0a12c51bde3446
# 2   c20b305988c7c42e0d12a97cec4b2cc01c79d1dd
# 3   4d8d746deaff9ee62ac63f1753b259d64ae73a72
# 4   12b437ac31598c07e86950f3e222cc0de16bd6a3
# 5   46a6a8c9567208e0ca49de7c97246ca954c46c62
# 6   832f4ea1b01d57fe326d81348ec5368f76168a71
# 7   b1d8f6b9828e55ac6680038e41114957db0570f8
# 8   6d9764a31946c0fe0ac40064f63bd614722da046
# 9   468bcbf7893980775a15cbbef2a10a110f5caf3c
# 10  382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc
# 11  338af8264b2122dba4309a13d4fbd84715113a6e
# 12  bce933756940ae0025e0ea1b1c2b12c6909161f3
# 13  5a2532c795cfb3cce5843080e7d144796de4fb2c
# 14  15a0f51296d29eb70d7f29f6113d3af93bbb3032
# 15                                       NaN
# 16  3b4c565822ba54d4297f8c6171729a57ffa499fc
# 17  7163e88f2a2880a7f7410f362b84cdc7237f2356
# 18  fd35099aaa6bc1913262e6be3d91a61277d21b94
# 19  af3fb301741793d1d481f1f6a91213c72c678dde
# 20  fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d
# 21  d860d12fe393274daae88bbafbfeee404204bec5
# 22  bfabaab502edb4f67e696edebade1b7e48875d6c
# 23  79bc6bc74ce60383260e639e59c10c1a89aaddd2
# 24  ea807f74bbd67bb865856e837b960bc9f5c5236c
# 25  2ee223000058e17daa85e9181d3fd13fe7adb395
# 26  4ddc4bb3ae0629df651e470587af85bf910ce041
# 27  8e72caa358e8e5239a8bc140fa6995c2fdcc713b
# 28  6d4e17ac9a8c69a7a2f867a08ea75e8bfe16213c
# 29  c5e207df710d3b445b48df4757608fc6d04af00c
#
#                                       payload.commits      org.id  \
# 0   [{'sha': '6289f6dc806212be1d87cad754f164c8a86e...  72746426.0
# 1   [{'sha': '679b379ca682313aa2e4fc4272e0e3b204c5...  72746426.0
# 2   [{'sha': '1270664c79d70fb78070bb79fb0a12c51bde...  72746426.0
# 3   [{'sha': 'c20b305988c7c42e0d12a97cec4b2cc01c79...  72746426.0
# 4   [{'sha': 'ba26d1043b77bfd35ad3ed0bb21add261ecb...  72746426.0
# 5   [{'sha': '12b437ac31598c07e86950f3e222cc0de16b...  72746426.0
# 6   [{'sha': '46a6a8c9567208e0ca49de7c97246ca954c4...  72746426.0
# 7   [{'sha': '832f4ea1b01d57fe326d81348ec5368f7616...  72746426.0
# 8   [{'sha': 'b1d8f6b9828e55ac6680038e41114957db05...  72746426.0
# 9   [{'sha': '6d9764a31946c0fe0ac40064f63bd614722d...  72746426.0
# 10  [{'sha': '468bcbf7893980775a15cbbef2a10a110f5c...  72746426.0
# 11  [{'sha': '382e12a8dc0e46b1bb34f1eaffd8b9704bbf...  72746426.0
# 12  [{'sha': '338af8264b2122dba4309a13d4fbd8471511...  72746426.0
# 13  [{'sha': 'bce933756940ae0025e0ea1b1c2b12c69091...  72746426.0
# 14  [{'sha': '5a2532c795cfb3cce5843080e7d144796de4...  72746426.0
# 15                                                NaN         NaN
# 16  [{'sha': '15a0f51296d29eb70d7f29f6113d3af93bbb...  72746426.0
# 17  [{'sha': '3b4c565822ba54d4297f8c6171729a57ffa4...  72746426.0
# 18  [{'sha': '715975215999642a75b2dde2475ff10cc123...  72746426.0
# 19  [{'sha': 'fd35099aaa6bc1913262e6be3d91a61277d2...  72746426.0
# 20  [{'sha': '15e27b2ecb73df710a567f34dd3c2ba71560...  72746426.0
# 21  [{'sha': 'fec9142fb2f13c7cfe5c5e7d2445a59d939d...  72746426.0
# 22  [{'sha': 'd860d12fe393274daae88bbafbfeee404204...  72746426.0
# 23  [{'sha': 'bfabaab502edb4f67e696edebade1b7e4887...  72746426.0
# 24  [{'sha': '79bc6bc74ce60383260e639e59c10c1a89aa...  72746426.0
# 25  [{'sha': 'e836d3cc8ec3b0f7950c907a1f524c877ce6...  72746426.0
# 26  [{'sha': '8c471c582ded0906fa528ceb67c8f48ac8de...  72746426.0
# 27  [{'sha': '829c0d752c95f5d4e3b2bc8e8809f51a30cb...  72746426.0
# 28  [{'sha': '6bb68f66c0dae9d3ec587cce77b5cad7b8f7...  72746426.0
# 29  [{'sha': 'ea807f74bbd67bb865856e837b960bc9f5c5...  72746426.0
#
#                     org.login org.gravatar_id  \
# 0   student-IH-labs-and-stuff
# 1   student-IH-labs-and-stuff
# 2   student-IH-labs-and-stuff
# 3   student-IH-labs-and-stuff
# 4   student-IH-labs-and-stuff
# 5   student-IH-labs-and-stuff
# 6   student-IH-labs-and-stuff
# 7   student-IH-labs-and-stuff
# 8   student-IH-labs-and-stuff
# 9   student-IH-labs-and-stuff
# 10  student-IH-labs-and-stuff
# 11  student-IH-labs-and-stuff
# 12  student-IH-labs-and-stuff
# 13  student-IH-labs-and-stuff
# 14  student-IH-labs-and-stuff
# 15                        NaN             NaN
# 16  student-IH-labs-and-stuff
# 17  student-IH-labs-and-stuff
# 18  student-IH-labs-and-stuff
# 19  student-IH-labs-and-stuff
# 20  student-IH-labs-and-stuff
# 21  student-IH-labs-and-stuff
# 22  student-IH-labs-and-stuff
# 23  student-IH-labs-and-stuff
# 24  student-IH-labs-and-stuff
# 25  student-IH-labs-and-stuff
# 26  student-IH-labs-and-stuff
# 27  student-IH-labs-and-stuff
# 28  student-IH-labs-and-stuff
# 29  student-IH-labs-and-stuff
#
#                                               org.url  \
# 0   https://api.github.com/orgs/student-IH-labs-an...
# 1   https://api.github.com/orgs/student-IH-labs-an...
# 2   https://api.github.com/orgs/student-IH-labs-an...
# 3   https://api.github.com/orgs/student-IH-labs-an...
# 4   https://api.github.com/orgs/student-IH-labs-an...
# 5   https://api.github.com/orgs/student-IH-labs-an...
# 6   https://api.github.com/orgs/student-IH-labs-an...
# 7   https://api.github.com/orgs/student-IH-labs-an...
# 8   https://api.github.com/orgs/student-IH-labs-an...
# 9   https://api.github.com/orgs/student-IH-labs-an...
# 10  https://api.github.com/orgs/student-IH-labs-an...
# 11  https://api.github.com/orgs/student-IH-labs-an...
# 12  https://api.github.com/orgs/student-IH-labs-an...
# 13  https://api.github.com/orgs/student-IH-labs-an...
# 14  https://api.github.com/orgs/student-IH-labs-an...
# 15                                                NaN
# 16  https://api.github.com/orgs/student-IH-labs-an...
# 17  https://api.github.com/orgs/student-IH-labs-an...
# 18  https://api.github.com/orgs/student-IH-labs-an...
# 19  https://api.github.com/orgs/student-IH-labs-an...
# 20  https://api.github.com/orgs/student-IH-labs-an...
# 21  https://api.github.com/orgs/student-IH-labs-an...
# 22  https://api.github.com/orgs/student-IH-labs-an...
# 23  https://api.github.com/orgs/student-IH-labs-an...
# 24  https://api.github.com/orgs/student-IH-labs-an...
# 25  https://api.github.com/orgs/student-IH-labs-an...
# 26  https://api.github.com/orgs/student-IH-labs-an...
# 27  https://api.github.com/orgs/student-IH-labs-an...
# 28  https://api.github.com/orgs/student-IH-labs-an...
# 29  https://api.github.com/orgs/student-IH-labs-an...
#
#                                        org.avatar_url
# 0   https://avatars.githubusercontent.com/u/72746426?
# 1   https://avatars.githubusercontent.com/u/72746426?
# 2   https://avatars.githubusercontent.com/u/72746426?
# 3   https://avatars.githubusercontent.com/u/72746426?
# 4   https://avatars.githubusercontent.com/u/72746426?
# 5   https://avatars.githubusercontent.com/u/72746426?
# 6   https://avatars.githubusercontent.com/u/72746426?
# 7   https://avatars.githubusercontent.com/u/72746426?
# 8   https://avatars.githubusercontent.com/u/72746426?
# 9   https://avatars.githubusercontent.com/u/72746426?
# 10  https://avatars.githubusercontent.com/u/72746426?
# 11  https://avatars.githubusercontent.com/u/72746426?
# 12  https://avatars.githubusercontent.com/u/72746426?
# 13  https://avatars.githubusercontent.com/u/72746426?
# 14  https://avatars.githubusercontent.com/u/72746426?
# 15                                                NaN
# 16  https://avatars.githubusercontent.com/u/72746426?
# 17  https://avatars.githubusercontent.com/u/72746426?
# 18  https://avatars.githubusercontent.com/u/72746426?
# 19  https://avatars.githubusercontent.com/u/72746426?
# 20  https://avatars.githubusercontent.com/u/72746426?
# 21  https://avatars.githubusercontent.com/u/72746426?
# 22  https://avatars.githubusercontent.com/u/72746426?
# 23  https://avatars.githubusercontent.com/u/72746426?
# 24  https://avatars.githubusercontent.com/u/72746426?
# 25  https://avatars.githubusercontent.com/u/72746426?
# 26  https://avatars.githubusercontent.com/u/72746426?
# 27  https://avatars.githubusercontent.com/u/72746426?
# 28  https://avatars.githubusercontent.com/u/72746426?
# 29  https://avatars.githubusercontent.com/u/72746426?
#
# [30 rows x 24 columns]

# %% [markdown]
# # Random pointless apis

# %%
response=requests.get('https://api.agify.io?name=sian')

# %%
response.content
# Out:
# b'{"name":"sian","age":50,"count":1337}'

# %%
type(response.content)
# Out:
# bytes

# %%
response=requests.get('https://api.nationalize.io?name=sian')

# %%
response.content
# Out:
# b'{"name":"sian","country":[{"country_id":"GB","probability":0.7679432638846571},{"country_id":"MY","probability":0.1704197578464618},{"country_id":"","probability":0.046867950112622875}]}'

# %%
my_json=json.loads(response.content)

# %%
my_json
# Out:
# {'name': 'sian',
#  'country': [{'country_id': 'GB', 'probability': 0.7679432638846571},
#   {'country_id': 'MY', 'probability': 0.1704197578464618},
#   {'country_id': '', 'probability': 0.046867950112622875}]}

# %%
new=pd.DataFrame(my_json)

# %%
new
# Out:
#    name                                            country
# 0  sian  {'country_id': 'GB', 'probability': 0.76794326...
# 1  sian  {'country_id': 'MY', 'probability': 0.17041975...
# 2  sian  {'country_id': '', 'probability': 0.0468679501...

# %%
# what should i do if im bored 
response=requests.get('https://www.boredapi.com/api/activity')

# %%
response.content
# Out:
# b'{"activity":"Organize your dresser","type":"busywork","participants":1,"price":0,"link":"","key":"7556665","accessibility":1}'

# %% [markdown]
# # International space station

# %%
# install folium on your conda env

# %%
import folium

# %%
response=requests.get('http://api.open-notify.org/iss-now.json')

# %%
response.json()
# Out:
# {'timestamp': 1653401355,
#  'iss_position': {'latitude': '25.5888', 'longitude': '21.2728'},
#  'message': 'success'}

# %%
latlong=[response.json()['iss_position']['latitude'],response.json()['iss_position']['longitude']]

# %%
mappy=folium.Map(location=latlong,zoom_starts=5)
#mappy

# %%
icon=folium.Icon(color='pink',
                prefix='fa',
                icon='rocket',
                icon_color='black',)

# %%
icon_data={'location':latlong,'tooltip':'ISS','icon':icon}

# %%
iss_marker=folium.Marker(**icon_data)

# %%
iss_marker.add_to(mappy);

# %%
mappy
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4b8b6242b14747a7b3666d0c6027b0b4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4b8b6242b14747a7b3666d0c6027b0b4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4b8b6242b14747a7b3666d0c6027b0b4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4b8b6242b14747a7b3666d0c6027b0b4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B25.5888%2C%2021.2728%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## passing information TO the api request

# %%
coordinates={"lat":52.06132, "lon":-0.47708, "n":10}
response=requests.get('http://api.open-notify.org/iss-pass.json',params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1653401715,
#   'latitude': 52.06132,
#   'longitude': -0.47708,
#   'passes': 10},
#  'response': [{'duration': 392, 'risetime': 1653407066},
#   {'duration': 614, 'risetime': 1653412704},
#   {'duration': 652, 'risetime': 1653418471},
#   {'duration': 653, 'risetime': 1653424274},
#   {'duration': 631, 'risetime': 1653430079},
#   {'duration': 487, 'risetime': 1653435911},
#   {'duration': 218, 'risetime': 1653490691},
#   {'duration': 586, 'risetime': 1653496244},
#   {'duration': 649, 'risetime': 1653501991},
#   {'duration': 654, 'risetime': 1653507790}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1653507790)
# Out:
# datetime.datetime(2022, 5, 25, 21, 43, 10)

# %% [markdown]
# # passing a authorisation key to the api

# %%
const options = {
  method: 'GET',
  url: 'https://cocktails3.p.rapidapi.com/random',
  headers: {
    'X-RapidAPI-Host': 'cocktails3.p.rapidapi.com',
    'X-RapidAPI-Key': '7a7b77879fmsh7f229a55585446cp11e799jsna7f7eb740123'
  }
};

# %%
response=requests.get(f'https://cocktails3.p.rapidapi.com/random',
  headers = {
    'X-RapidAPI-Host': 'cocktails3.p.rapidapi.com',
    'X-RapidAPI-Key': '7a7b77879fmsh7f229a55585446cp11e799jsna7f7eb740123'
  }
                     )

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'success': True,
#  'body': [{'name': 'charred pineapple margarita',
#    'ingredients': ['Patron Extra Añejo Tequila - 1.5oz',
#     'Fresh Pineapple Juice - 0.75oz',
#     'Green Chile Liqueur - 0.25oz',
#     'Burnt Sugar Simple Syrup - 0.25oz',
#     'Blue Agave Nectar - 0.25oz',
#     'Fresh Lime Juice - 1oz',
#     'Habanero Bitters - 5 Drops',
#     'Fresh Cucumber - 2 Slices',
#     'Smoked Salt - 1 Large Pinch',
#     'Charred Pineapple & Dehydrated Lime Wesge Garnish']}]}

# %%
response=requests.get('https://cocktails3.p.rapidapi.com/random')

# %%
response.status_code
# Out:
# 401
